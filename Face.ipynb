# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\MACHINE LEARNING PROJECTS\Face Puching - Open CV\Book1.csv", sep="\t")

import cv2

# %%
face_cascade = cv2.CascadeClassifier(r"C:\MACHINE LEARNING PROJECTS\Face Puching - Open CV\haarcascade_frontalface_default (1).xml")
cam = cv2.VideoCapture(0)

# %%
id = input("Enter your id")
name = input("enter your name")
df2 = pd.DataFrame({"id":[id],"Name":[name]})
df = pd.concat([df,df2]).drop_duplicates().reset_index(drop=True)
df.to_csv(r"C:\MACHINE LEARNING PROJECTS\Face Puching - Open CV\Book1.csv",index=False)

sampleNum =
