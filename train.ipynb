# %%
import os
import cv2
import numpy as np # train file
from PIL import Image
recognizer=cv2.face.LBPHFaceRecognizer_create()
path=r"C:\MACHINE LEARNING PROJECTS\Face Puching - Open CV\faces"

def getImagesWithID(path):
    imagePaths=[os.path.join(path,f) for f in os.listdir(path)]
    faces=[]
    IDs=[]
    for imagePath in imagePaths:
        faceImg=Image.open(imagePath).convert('L')
        faceNp=np.array(faceImg,'uint8')
        ID=int(os.path.split(imagePath)[-1].split('.')[1])
        faces.append(faceNp)
        IDs.append(ID)
        cv2.imshow("training",faceNp)
        cv2.waitKey(100) # for 10 milliseconds wait......
    return np.array(IDs), faces

Ids, faces=getImagesWithID(path)
recognizer.train(faces,np.array(Ids))
recognizer.save("C:\MACHINE LEARNING PROJECTS\Face Puching - Open CV\trainningData.yml")
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 5
#       3 import numpy as np # train file
#       4 from PIL import Image
# ----> 5 recognizer=cv2.face.LBPHFaceRecognizer_create()
#       6 path=r"C:\MACHINE LEARNING PROJECTS\Face Puching - Open CV\faces"
#       8 def getImagesWithID(path):
#
# AttributeError: module 'cv2' has no attribute 'face'
